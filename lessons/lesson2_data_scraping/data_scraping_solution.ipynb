# %%
"""
Process:
1. Request data (html, css, javascript) from web page
2. Structure html to enable the identification and extraction of html
3. Identify, extract, and store

Slide of libraries, patterns, syntax
Slide of request, html, extract tag, store in list, iterate through, download, store locally
"""


import os
import time

# %% [markdown]
# ### Python String Formatting
#
# We will use string formatting to create clean, readable strings many of the lessons. For this, we will use str.format()
#
# - str.format() examples: https://pyformat.info/

# %%
'This is a python string'
# Out:
# 'This is a python string'

# %%
'We can add a parameter {}'.format('in the string using {}')
# Out:
# 'We can add a parameter in the string using {}'

# %%
'{}'.format('.format() fills in the parameter braces')
# Out:
# '.format() fills in the parameter braces'

# %%
'.format() allows multiple parameters, of any datatype: param {}, param {},  param {}'.format('one', 2, 3.0)
# Out:
# '.format() allows multiple parameters, of any datatype: param one, param 2,  param 3.0'

# %%
# formatting is useful for changing strings as part of a loop
urls = ['url1','url2','url3']

for url in urls:
    print('Successfully requested data from {}'.format(url))
# Out:
# Successfully requested data from url1
# Successfully requested data from url2
# Successfully requested data from url3

# %% [markdown]
# ### REQUESTS
#
# Requests is a Python HTTP library, released under the Apache2 License. The goal of the project is to make HTTP requests simpler and more human-friendly. We will use requests to get html, css, and javascript from webpages to collect data from the web.

# %%
from IPython.core.display import display, HTML

requests_url = 'http://docs.python-requests.org/en/master/'
iframe = '<iframe src={} width=1100 height=300></iframe>'.format(requests_url)
HTML(iframe)
# Out:
# <iframe src=http://docs.python-requests.org/en/master/ width=1100 height=300></iframe>

# %%
import requests

# set a url for deloitte's website homepage
deloitte_url = r'https://www2.deloitte.com/us/en.html'

# r is the common name for a requests instance
r = requests.get(deloitte_url)

# %% [markdown]
# #### Two commonly used methods for a request-response between a client and server are: GET and POST.
# - GET - Requests data from a specified resource
# - POST - Submits data to be processed to a specified resource
#
#
# #### Client-side vs Server-side Programming Languages
#
# Web development is all about communication and data exchange. This communication takes place via two parties over the HTTP protocol.
#
# - Server: The Server is responsible for serving the web pages depending on the client/end user requirement. It can be either static or dynamic.
# - Client: A client is a party that requests pages from the server and displays them to the end user. In general a client program is a web browser.
#
# source: http://www.c-sharpcorner.com/UploadFile/2072a9/client-side-vs-server-side-programming-languages/

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# #### Status Code Explanation
# When a browser requests a service from a web server, an error might occur. The first digit of the status code specifies one of five standard classes of responses.
#
# - 1xx: Information
# - 2xx: Successful
# - 3xx: Redirection
# - 4xx: Client Error
# - 5xx: Server Error
#
# https://en.wikipedia.org/wiki/List_of_HTTP_status_codes

# %%
r.text
# Out:
# '\n<!DOCTYPE HTML>\n\n\n\n\n    <html lang="en">\n\n        <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\n        \t\n<meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">\n      \n    <script>\n\t\tvar dtmConfig = true;\n\t\tvar siteCatConfig = false;\n        // Added the below to fetch the Twine Social parameters\n        var twineSocialClientID = "MTY1ODcsUk9mSlVLWFdWQlZBTzdHWmFWQzVoRzlvTXd2c24wcjU%3D";\n        var twineSocialAccountCode = "15-I7FFXT";\n        var twineSocialGroupID = "96432072593";\n\t</script>\n\n    <meta charset="utf-8"> \n    \n    <meta name=\'description\' content="Deloitte provides industry-leading audit, consulting, tax, and advisory services to many of the world’s most admired brands, including 80 percent of the Fortune 500. As a member firm of Deloitte Touche Tohmatsu Limited, a network of member firms, we are proud to be part of the largest global professional services network, serving our clients in the markets that are most important to them.">\n\t\n\t\n    <link rel="canonical" href="https://www2.deloitte.com/us/en.html"/>\n\t\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\t<meta property="fb:app_id" content="391573044299401">\n    <meta property="og:type" content="website">\n    <meta property="og:site_name" content="Deloitte United States">\n    <meta property="og:url" content="https://www2.deloitte.com/us/en.html">\n    <meta name="twitter:card" content="summary">\n    <meta name="twitter:site" content="@DeloitteUS">\n    <meta name="twitter:url" content="https://www2.deloitte.com/us/en.html">\n    \n    <title>Deloitte US | Audit, consulting, advisory, and tax services </title>\n    <meta property="og:title" content="Deloitte US | Audit, consulting, advisory, and tax services ">\n    <meta name="twitter:title" content="Deloitte US | Audit, consulting, advisory, and tax services ">\n    <meta property="og:description" content="Deloitte provides industry-leading audit, consulting, tax, and advisory services to many of the world’s most admired brands, including 80 percent of the Fortune 500. As a member firm of Deloitte Touche Tohmatsu Limited, a network of member firms, we are proud to be part of the largest global professional services network, serving our clients in the markets that are most important to them.">\n    <meta name="twitter:description" content="Deloitte provides industry-leading audit, consulting, tax, and advisory services to many of the world’s most admired brands, including 80 percent of the Fortune 500. As a member firm of Deloitte Touche Tohmatsu Limited, a network of member firms, we are proud to be part of the largest global professional services network, serving our clients in the markets that are most important to them.">\n    \n    \n    \n    \n    \n        <script>\n        if(window.location.host=="www2.deloitte.com"){\n            var _prum = [[\'id\', \'55674bb3abe53dc97723bf6b\'],\n                         [\'mark\', \'firstbyte\', (new Date()).getTime()]];\n            (function() {\n                var s = document.getElementsByTagName(\'script\')[0]\n                , p = document.createElement(\'script\');\n                p.async = \'async\';\n                p.src = \'//rum-static.pingdom.net/prum.min.js\';\n                s.parentNode.insertBefore(p, s);\n            })();\n        }\n        </script>\n    \n\n    \n    <link rel="icon" type="image/vnd.microsoft.icon" href="/content/dam/resources/deloitte/icons/favicon.ico">\n    <link rel="shortcut icon" type="image/vnd.microsoft.icon" href="/content/dam/resources/deloitte/icons/favicon.ico">\n    <link rel="apple-touch-icon" sizes="57x57" href="/content/dam/resources/deloitte/icons/apple-icon-57x57.png"/>\n    <link rel="apple-touch-icon" sizes="72x72" href="/content/dam/resources/deloitte/icons/apple-icon-72x72.png"/>\n    <link rel="apple-touch-icon ...

# %%
r.encoding
# Out:
# 'UTF-8'

# %% [markdown]
# #### Requests text and encoding
#
# Requests will automatically decode content from the server. Most unicode charsets are seamlessly decoded. When you make a request, Requests makes educated guesses about the encoding of the response based on the HTTP headers.
#
# The text encoding guessed by Requests is used when you access r.text. You can find out what encoding Requests is using, and change it, using the r.encoding property:
#
# - What is the difference between unicode and ascii: https://stackoverflow.com/questions/19212306/whats-the-difference-between-ascii-and-unicode

# %% [markdown]
# ### Beautiful Soup
#
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.

# %%
bs_url = 'https://www.crummy.com/software/BeautifulSoup/bs4/doc/'
iframe = '<iframe src=' + bs_url + ' width=1100 height=300></iframe>'
HTML(iframe)
# Out:
# <iframe src=https://www.crummy.com/software/BeautifulSoup/bs4/doc/ width=1100 height=300></iframe>

# %%
from bs4 import BeautifulSoup

b = BeautifulSoup(r.text, 'lxml')

# %%
# BeautifulSoup structures the text, removing unnecessary 
# newline \n and tab \t characters
b
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script>
# 		var dtmConfig = true;
# 		var siteCatConfig = false;
#         // Added the below to fetch the Twine Social parameters
#         var twineSocialClientID = "MTY1ODcsUk9mSlVLWFdWQlZBTzdHWmFWQzVoRzlvTXd2c24wcjU%3D";
#         var twineSocialAccountCode = "15-I7FFXT";
#         var twineSocialGroupID = "96432072593";
# 	</script>
# <meta charset="utf-8"/>
# <meta content="Deloitte provides industry-leading audit, consulting, tax, and advisory services to many of the world’s most admired brands, including 80 percent of the Fortune 500. As a member firm of Deloitte Touche Tohmatsu Limited, a network of member firms, we are proud to be part of the largest global professional services network, serving our clients in the markets that are most important to them." name="description"/>
# <link href="https://www2.deloitte.com/us/en.html" rel="canonical"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="391573044299401" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="Deloitte United States" property="og:site_name"/>
# <meta content="https://www2.deloitte.com/us/en.html" property="og:url"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@DeloitteUS" name="twitter:site"/>
# <meta content="https://www2.deloitte.com/us/en.html" name="twitter:url"/>
# <title>Deloitte US | Audit, consulting, advisory, and tax services </title>
# <meta content="Deloitte US | Audit, consulting, advisory, and tax services " property="og:title"/>
# <meta content="Deloitte US | Audit, consulting, advisory, and tax services " name="twitter:title"/>
# <meta content="Deloitte provides industry-leading audit, consulting, tax, and advisory services to many of the world’s most admired brands, including 80 percent of the Fortune 500. As a member firm of Deloitte Touche Tohmatsu Limited, a network of member firms, we are proud to be part of the largest global professional services network, serving our clients in the markets that are most important to them." property="og:description"/>
# <meta content="Deloitte provides industry-leading audit, consulting, tax, and advisory services to many of the world’s most admired brands, including 80 percent of the Fortune 500. As a member firm of Deloitte Touche Tohmatsu Limited, a network of member firms, we are proud to be part of the largest global professional services network, serving our clients in the markets that are most important to them." name="twitter:description"/>
# <script>
#         if(window.location.host=="www2.deloitte.com"){
#             var _prum = [['id', '55674bb3abe53dc97723bf6b'],
#                          ['mark', 'firstbyte', (new Date()).getTime()]];
#             (function() {
#                 var s = document.getElementsByTagName('script')[0]
#                 , p = document.createElement('script');
#                 p.async = 'async';
#                 p.src = '//rum-static.pingdom.net/prum.min.js';
#                 s.parentNode.insertBefore(p, s);
#             })();
#         }
#         </script>
# <link href="/content/dam/resources/deloitte/icons/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="/content/dam/resources/deloitte/icons/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="/content/dam/resources/deloitte/icons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/content/dam/resources/deloitte/icons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/content/dam/resources/deloitte/icons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/content/dam/resources/deloitte/icons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <meta content="/content/dam/resources/deloitte/browserconfig.xml" name="msapplication-config"/>
# <script type="text/javascript">
#
# 		if(/MSIE (8\.[\.0-9]{0,})|MSIE (7\.[\.0-9]{0,})|MSIE (6\.[\.0-9]{0,})/i.test(navigator.userAgent)) {
# 		window.location.href= "/us/en/misc/nonsupportedbrowserpage.us.en.html";
# 	}
#
# 	var domain = 'https://www2.deloitte.com/';
# 	var isEditMode = 'false';
# 	var isDesignMode = 'false';
# 	var sc_currentPageName = '/us/en';
# 	var sc_currentPageHashValue = 'd6ec5039';
# 	var sc_template = 'Deloitte_Member_Firm_Home_Page_Template';
# 	var sc_recCuratedPromos = '';
# 	var sc_recommArticle = 'Recommendations';
# 	var sc_recViewedPage = 'Recently viewed pages';
# 	var sc_channel = '';
# 	var hideFromRecommendations = 'true';
# 	var pagePathValue = '/us/en';
# 	var selectorString = '.';
# 	var siteSectionOverrideVal = '';
# 	var PAGE_NAME = "";
# 	var GOOGLE_MF_ACCOUNT = "";
# 	var GOOGLE_INCLUDE_GLOBAL = "";
# 	var RESULTS_FOR_LBL = "";
# 	var sc_secondLevelForProp5 = "";
# 	var temp_Name = 'memberfirmhomepage';
# 	var isTempSite = false;
# 	var sc_secondLevel = '';
# 	var sc_thirdLevel = '';
# 	var sc_country = 'us';
# 	var sc_language = 'en';
# 	var siteOverrideValueProp5 = 'us';
#
# 	if(siteSectionOverrideVal.length > 0 && (siteSectionOverrideVal.toUpperCase().trim() == 'NA')){
# 		siteOverrideValueProp5='';
# 	}else if((siteSectionOverrideVal.length > 0 && siteSectionOverrideVal.toUpperCase().trim() != 'NA')){
# 		siteOverrideValueProp5 = siteSectionOverrideVal.toLowerCase().trim();
# 	}else if(siteSectionOverrideVal.length == 0){
# 		if(temp_Name == 'genericerrorpage'){
# 			siteOverrideValueProp5 = '404_error';
# 		}
# 		else if(temp_Name == 'nonsupportedpage'){
# 			siteOverrideValueProp5 = 'not_supported';
# 		}else if((temp_Name == 'rfpformpage') || (temp_Name == 'contactuspage')|| (temp_Name == 'deloitteformstemplate')){
# 			siteOverrideValueProp5 = 'forms';
# 		}else if((temp_Name == 'searchResultsTemplate') || (temp_Name == 'googleSearchResultsTemplate')){
# 			siteOverrideValueProp5 = 'search_results';
# 		}else if((temp_Name == 'officedetailspage') || (temp_Name == 'officelocatorpage')|| (temp_Name == 'globalofficedirectorypage')){
# 			siteOverrideValueProp5 = 'office_information';
# 		}else if(temp_Name == 'companyinformationpage'){
# 			siteOverrideValueProp5 = 'legal';
# 		}else if(temp_Name == 'moreondeloittepage'){
# 			siteOverrideValueProp5 = 'company_information';
# 		}else if(temp_Name == 'pressreleasespagetemplate'){
# 			siteOverrideValueProp5 = 'press_releases';
# 		}else if((temp_Name == 'fulltopicpage') || (temp_Name == 'articlepage')|| (temp_Name == 'solutionpage')|| (temp_Name == 'eventpage')|| (temp_Name == 'careerpage')){
# 			siteOverrideValueProp5 ='us';
# 		}else if(temp_Name == "memberfirmhomepage" || temp_Name == "globalhomepage") {
# 			siteOverrideValueProp5 = 'home';
# 		}else if(temp_Name == "thankyoupage") {
# 			siteOverrideValueProp5 = 'thank_you';
# 		}else if(temp_Name == "dynamiclisttemplate") {
# 			siteOverrideValueProp5 = 'dynamiclist';
# 		}else if(temp_Name == "htmlfragmentpage") {
# 			siteOverrideValueProp5 = 'landingpage';
# 		}
# 	}
#
# 	if(temp_Name == "memberfirmhomepage" || temp_Name == "globalhomepage") {
# 		 sc_channel = 'Homepage';
# 	} else if(temp_Name == "thankyoupage") {
# 	   sc_channel = 'Thankyou';
# 	}
# 	sc_secondLevelForProp5 = siteOverrideValueProp5;
# 	searchLocation = '//www2.deloitte.com/us/en/misc/search.html';
#
# </script>
# <script type="text/javascript">
#         /*For checking external link in external dynamic promos*/
#         function checkExternalLink (url) {
#             var path = url.split("|");
#             if(path[1] != undefined){
#                 url = path[path.length-1];
#             }
#             return url;
#         }
#     </script>
# <script type="text/javascript">
# 	    var isTMP = false;
# 	    var siteDomain = "";
# 	    if(isTMP) {
# 	    	siteDomain = domain;
# 	    	if(siteDomain != "") {
# 	    		siteDomain=domain.slice(0,-1);
# 	         if(siteDomain.indexOf(":")+1){
# 	        	 siteDomain=siteDomain.substr(siteDomain.indexOf(":")+1);
# 	         }
# 	       }
# 	    }
#     </script>
# <script type="text/javascript"></script>
# <link href="/etc/designs/dcom/dcom-main.min.1407171800.css" rel="stylesheet" type="text/css"/>
# <script src="/etc/designs/dcom/dcom-main.min.1407171800.js" type="text/javascript"></script>
# <script type="text/javascript">
#         var memberFirmSNPURL = 'http://sp10050c00.guided.ss-omtrdc.net/';
#
#         /* if current request is https (secure), then hitting the secure S&P interface by replacing http with https  */
#             if(document.URL.indexOf('https') > -1) {
#                 memberFirmSNPURL = memberFirmSNPURL.replace("http://", "https://");
#             }
#         var currentPageTitle ='Deloitte US';
#         var homePageExclusionList = 'd6ec5039 4f77dd1c 2196bec 7fba4318 858d5f1f acc79d1b fea539df';
# 		var contentPromosExclusionList = 'd6ec5039 4f77dd1c 2196bec 7fba4318 858d5f1f acc79d1b fea539df';
#         var pageProtocol="https:";
#     </script>
# <script src="/etc/designs/dcom/clientlibs-homepage.min.1407171800.js" type="text/javascript"></script>
# <script src="//assets.adobedtm.com/e1ba6f669774dd2a2e76f2e3972ef3cc8756c951/satelliteLib-7dae94e32584fbfd2f3ac21bacda178a6020b044.js"></script>
# </head>
# <body ng-app="appModule" ng-controller="appController">
# <noscript>
# <div style="background: #fbfbfb; color: red; border: 1px solid #DCDCDC; width: 95%; margin: 20px auto; padding: 20px; text-align: center; font-size: 16px; font-weight: 300; font-family: 'Open Sans', sans-serif;">
# 		Please enable JavaScript to view the site.
# 	</div>
# </noscript>
# <script>
#     var dataLayer= {};
#     var custom_data_1 = '';
#     var custom_data_2 = '';
#     if(custom_data_1.length > 0){
#     	custom_data_1 =sc_country + ';' + sc_language +'_'+ (custom_data_1.toLowerCase()).replace(/ /g,"_");
#     }
#     if(custom_data_2.length > 0){
#     	custom_data_2 =sc_country + ';' + sc_language +'_'+ (custom_data_2.toLowerCase()).replace(/ /g,"_");
#     }
#
#     function getCookie(name)
#     {
#         var dc = document.cookie;
#         var prefix = name + "=";
#         var begin = dc.indexOf("; " + prefix);
#         if (begin == -1) {
#             begin = dc.indexOf(prefix);
#             if (begin != 0) return null;
#         }
#         else
#         {
#             begin += 2;
#             var end = document.cookie.indexOf(";", begin);
#             if (end == -1) {
#                 end = dc.length;
#             }
#         }
#         return unescape(dc.substring(begin + prefix.length, end));
#     }
#
#
# 	var promoIds_attributes='';
# 	var tagNames_attributes='';
# 	var promoIds_disc_more='';
# 	var tagNames_disc_more='';
# 	var promoIds_next_steps='';
# 	var promoIds_trending='';
# </script>
# <div id="gigya-container" style="display: none;">
# </div>
# <header class="clearfix " id="header" role="banner">
# <div class="header-wrapper">
# <div class="header-container clearfix">
# <button aria-expanded="false" aria-label="Menu" class="header-button mobile-nav-button" type="button">
# <i class="icon-navicon"></i>
# </button>
# <div class="column logo">
# <a class="deloitte-logo" href="/us/en.html" title="United States"> <!-- Put image source value here along with width and height -->
# <img alt="United States" class="logo-deloitte" height="34" src="/content/dam/assets/logos/deloitte.svg" width="182"/>
# <img alt="" class="logo-print" height="34" src="/content/dam/assets/logos/deloitte-print.png" width="182"/>
# </a>
# <div class="annotations"></div>
# </div>
# <button aria-expanded="false" aria-label="Search" class="header-button mobile-search-button" type="button">
# <i class="icon-search"></i>
# </button>
# <div class="search column clearfix"><button aria-expanded="false" aria-label="Close" class="mobile-search-close" type="button"> <i class="icon-remove"></i> </button>
# <div class="search"><script type="text/javascript">
#     var cse_sig = CQ.shared.XSS.getXSSValue('ee93f9aae9c9e9dba5eea831d506e69a');
#     var	cse_key = CQ.shared.XSS.getXSSValue('AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY');
#     var cse_cx = CQ.shared.XSS.getXSSValue('008113462624956073801:');
#     var cse_all = CQ.shared.XSS.getXSSValue('Dcom-All');
#     var cse_local = CQ.shared.XSS.getXSSValue('Dcom-UnitedStates');
#     var cse_hl = CQ.shared.XSS.getXSSValue('en');
#     var cse_AllResultsLabel,Current_page_key,phone_key, By_key,viewmap_key, cse_AllResultsLabel,View_page_key, resultsPage;
# </script>
# <div id="header-search">
# <form id="gSearchForm" ng-submit="searchSubmit()" role="search">
# <input autocomplete="off" class="gsc-input" enableorderby="true" id="gSearch" name="qr" ng-model="result" placeholder="Search" title="search" type="text" typeahead-focus-first="false" typeahead-on-select="onSelect($item, $model, $label)" uib-typeahead="q for q in getAutoResult($viewValue)" x-webkit-speech=""/>
# <a href="" ng-click="searchSubmit()" title="Search"><i class="icon-search"></i></a>
# </form>
# </div>
# </div>
# </div>
# <nav class="column navigation">
# <ul class="topline-nav" id="header-utility-nav">
# <li class="about-link">
# <a href="/us/en/pages/about-deloitte/articles/about-deloitte.html">About Deloitte</a>
# </li>
# <li class="contactus-link"><a href="/us/en/footerlinks/contact-us.html?icid=top_contact-us.html">Contact us</a></li>
# <li class="countryselector">
# <span id="location">Location:</span> <a aria-expanded="false" aria-labelledby="location" class="location-link no-click-close" href="#" role="button"><span class="no-click-close">
# United States
# </span>  <i class="icon-chevron no-click-close"></i></a>
# <div id="header-site-selector">
# <div class="location-container visibility-hidden" id="site-options">
# <div role="search">
# <input autocomplete="off" class="gsc-input" enableorderby="true" id="siteSearch" name="qr" placeholder="Type location" size="10" spellcheck="false" title="search" type="text"/>
# <span class="icon-search search-option"></span>
# </div>
# <div id="site-selector">
# <ul class="channel-site no-click-close"></ul>
# </div>
# <!-- Site selector -->
# <div class="site-info">
# </div>
# </div>
# </div>
# </li>
# </ul>
# <div class="nav" role="navigation">
# <ul class="main-nav" role="menubar">
# <li aria-haspopup="true" class="subnav-item no-click-close" id="list1" role="menuitem">
# <a aria-haspopup="true" class="has-sub-nav no-click-close subnav-item-anchor" data-sub="Services" href="#" role="menuitem">
#                       Services<i class="icon-chevron no-click-close"></i>
# </a>
# <div aria-expanded="false" aria-labelledby="list1" class="sub-nav no-click-close">
# <div class="sub-nav-menu-wrapper">
# <div class="whats-new-section ">
# <strong>What's New</strong>
# <ul>
# <li class="no-click-close">
# <a class="no-click-close" href="http://dupress.deloitte.com/dup-us-en/home.html?icid=wn_" target="_blank">
# <strong>Read our latest thinking</strong>
# <p>Visit Deloitte Insights</p>
# </a>
# </li>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/dbriefs-webcasts/upcoming-webcasts.html?icid=wn_" target="_blank">
# <strong>Register for Dbriefs webcasts</strong>
# <p></p>
# </a>
# </li>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/operations/articles/deloitte-client-spotlight-success-stories-case-studies.html?icid=wn_deloitte-client-spotlight-success-stories-case-studies" target="_self">
# <strong>Real stories from real clients</strong>
# <p>Learn how our clients have realized true business transformation</p>
# </a>
# </li>
# </ul>
# </div>
# <div class="sub-nav-menu-items">
# <div class="menu-row">
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/services/tax.html?icid=top_tax" target="_self">
# <strong>Tax</strong>
# </a>
# <ul>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/tax/topics/business-tax.html?icid=top_business-tax" target="_self">
#                                                                           Global Business Tax Services</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/tax/topics/global-employer-services.html?icid=top_global-employer-services" target="_self">
#                                                                           Global Employer Services</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/tax/solutions/us-indirect-tax-services.html?icid=top_" target="_self">
#                                                                           Indirect Tax</a>
# </li>
# </div>
# </ul>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/services/consulting.html?icid=top_consulting" target="_self">
# <strong>Consulting</strong>
# </a>
# <ul>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/human-capital/topics/human-capital.html?icid=top_human-capital" target="_self">
#                                                                           Human Capital</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/strategy-operations/topics/strategy-and-operations-consulting.html?icid=top_strategy-and-operations-consulting" target="_self">
#                                                                           Strategy &amp; Operations</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/technology/topics/technology.html?icid=top_technology" target="_self">
#                                                                           Technology</a>
# </li>
# </div>
# </ul>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/services/audit.html?icid=top_audit" target="_self">
# <strong>Audit &amp; Assurance</strong>
# </a>
# </div>
# </div>
# <div class="menu-row">
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/services/deloitte-growth-enterprise-services.html?icid=top_deloitte-growth-enterprise-services" target="_self">
# <strong>Deloitte Growth Enterprise Services</strong>
# </a>
# <ul>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/deloitte-growth-enterprise-services/solutions/middle-market-services.html?icid=top_middle-market-services" target="_self">
#                                                                           Middle Market Services</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/deloitte-growth-enterprise-services/solutions/deloitte-private-company-services.html?icid=top_deloitte-private-company-services" target="_self">
#                                                                           Private Company Services</a>
# </li>
# </div>
# </ul>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/services/mergers-and-acquisitions.html?icid=top_mergers-and-acquisitions" target="_self">
# <strong>Mergers &amp; Acquisitions</strong>
# </a>
# <ul>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/mergers-and-acquisitions/solutions/total-mergers-and-acquisitions-solution.html?icid=top_total-mergers-and-acquisitions-solution" target="_self">
#                                                                           Total M&amp;A Solution</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/mergers-and-acquisitions/topics/post-merger-integration.html?icid=top_post-merger-integration" target="_self">
#                                                                           Post-merger Integration</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/mergers-and-acquisitions/topics/divestiture-and-separation.html?icid=top_divestiture-and-separation" target="_self">
#                                                                           Divestiture &amp; Separation</a>
# </li>
# </div>
# </ul>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/services/advisory.html?icid=top_advisory" target="_self">
# <strong>Risk and Financial Advisory</strong>
# </a>
# <ul>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/risk/topics/cyber-security.html?icid=top_cyber-security" target="_self">
#                                                                           Cyber Risk</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/advisory/topics/financial-risk.html?icid=top_financial-risk" target="_self">
#                                                                           Financial Risk, Transactions &amp; Restructuring</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/advisory/topics/forensic-advisory.html?icid=top_forensic-advisory" target="_self">
#                                                                           Forensic</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/risk/topics/internal-audit-and-assurance.html?icid=top_internal-audit-and-assurance" target="_self">
#                                                                           Internal Audit &amp; Assurance</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/regulatory/topics/regulatory-and-operational-risk.html?icid=top_regulatory-and-operational-risk" target="_self">
#                                                                           Regulatory &amp; Operational Risk</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/risk/topics/strategic-and-reputation-risk.html?icid=top_strategic-and-reputation-risk" target="_self">
#                                                                           Strategic &amp; Reputation Risk Management</a>
# </li>
# </div>
# </ul>
# </div>
# </div>
# <div class="menu-row">
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/pages/deloitte-analytics/topics/deloitte-analytics-services.html?icid=top_deloitte-analytics-services" target="_self">
# <strong>Analytics</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items empty">
# <a class="no-click-close">
# <strong></strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items empty">
# <a class="no-click-close">
# <strong></strong>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="subnav-item no-click-close" id="list2" role="menuitem">
# <a aria-haspopup="true" class="has-sub-nav no-click-close subnav-item-anchor" data-sub="Industries" href="#" role="menuitem">
#                       Industries<i class="icon-chevron no-click-close"></i>
# </a>
# <div aria-expanded="false" aria-labelledby="list2" class="sub-nav no-click-close">
# <div class="sub-nav-menu-wrapper">
# <div class="whats-new-section ">
# <strong>What's New</strong>
# <ul>
# <li class="no-click-close">
# <a class="no-click-close" href="http://dupress.deloitte.com/dup-us-en/home.html?icid=wn_" target="_blank">
# <strong>Read our latest thinking</strong>
# <p>Visit Deloitte Insights</p>
# </a>
# </li>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/dbriefs-webcasts/upcoming-webcasts.html?icid=wn_" target="_blank">
# <strong>Register for Dbriefs webcasts</strong>
# <p></p>
# </a>
# </li>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/operations/articles/deloitte-client-spotlight-success-stories-case-studies.html?icid=wn_deloitte-client-spotlight-success-stories-case-studies" target="_self">
# <strong>Real stories from real clients</strong>
# <p>Learn how our clients have realized true business transformation</p>
# </a>
# </li>
# </ul>
# </div>
# <div class="sub-nav-menu-items">
# <div class="menu-row">
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/consumer-industrial-products.html?icid=top_consumer-industrial-products" target="_self">
# <strong>Consumer &amp; Industrial Products</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/energy-and-resources.html?icid=top_energy-and-resources" target="_self">
# <strong>Energy &amp; Resources</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/financial-services.html?icid=top_financial-services" target="_self">
# <strong>Financial Services</strong>
# </a>
# </div>
# </div>
# <div class="menu-row">
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/life-sciences-and-health-care.html?icid=top_life-sciences-and-health-care" target="_self">
# <strong>Life Sciences &amp; Health Care</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/manufacturing.html?icid=top_manufacturing" target="_self">
# <strong>Manufacturing</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/public-sector.html?icid=top_public-sector" target="_self">
# <strong>Public Sector</strong>
# </a>
# </div>
# </div>
# <div class="menu-row">
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/real-estate.html?icid=top_real-estate" target="_self">
# <strong>Real Estate &amp; Construction</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/technology-media-and-telecommunications.html?icid=top_technology-media-and-telecommunications" target="_self">
# <strong>Technology, Media &amp; Telecommunications</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/industries/all-industries-sectors.html?icid=top_all-industries-sectors" target="_self">
# <strong>All Industries and Sectors</strong>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="subnav-item no-click-close" id="list3" role="menuitem">
# <a aria-haspopup="true" class="has-sub-nav no-click-close subnav-item-anchor" data-sub="Careers" href="#" role="menuitem">
#                       Careers<i class="icon-chevron no-click-close"></i>
# </a>
# <div aria-expanded="false" aria-labelledby="list3" class="sub-nav no-click-close">
# <div class="sub-nav-menu-wrapper">
# <div class="whats-new-section ">
# <strong>What's New</strong>
# <ul>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/careers/articles/job-search-map.html?icid=wn_job-search-map" target="_self">
# <strong>Job Map</strong>
# <p>Deloitte has more than 100 offices throughout the United States. Explore our interactive map to find jobs near you.</p>
# </a>
# </li>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/careers/topics/career-journeys.html?icid=wn_career-journeys" target="_self">
# <strong>Career Journeys</strong>
# <p>Our people and our culture make Deloitte a place where leaders thrive. Get an inside look at the rich diversity of background, education, and experiences of our people. </p>
# </a>
# </li>
# </ul>
# </div>
# <div class="sub-nav-menu-items">
# <div class="menu-row">
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="https://jobs2.deloitte.com/us/en/?icid=top_" target="_blank">
# <strong>Job Search</strong>
# </a>
# <ul>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="https://jobs2.deloitte.com/us/en/?icid=top_" target="_blank">
#                                                                           Home</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="https://jobs2.deloitte.com/us/en/Student-all-jobs?icid=top_" target="_blank">
#                                                                           Student Jobs</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="https://jobs2.deloitte.com/us/en/Experienced-all-jobs?icid=top_" target="_blank">
#                                                                           Experienced Hire Jobs</a>
# </li>
# </div>
# </ul>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/careers/students.html?icid=top_students" target="_self">
# <strong>Students</strong>
# </a>
# <ul>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/careers/articles/join-deloitte-on-campus.html?icid=top_join-deloitte-on-campus" target="_self">
#                                                                           On Campus</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/careers/articles/join-deloitte-undergraduate-degree-opportunities.html?icid=top_join-deloitte-undergraduate-degree-opportunities" target="_self">
#                                                                           Undergraduate</a>
# </li>
# </div>
# <div>
# <li class="no-click-close">
# <a class="no-click-close" href="/us/en/pages/careers/articles/join-deloitte-advanced-degree-opportunities.html?icid=top_join-deloitte-advanced-degree-opportunities" target="_self">
#                                                                           Advanced Degree</a>
# </li>
# </div>
# </ul>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/careers/experienced-hires.html?icid=top_experienced-hires" target="_self">
# <strong>Experienced Hires</strong>
# </a>
# </div>
# </div>
# <div class="menu-row">
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/careers/executives.html?icid=top_executives" target="_self">
# <strong>Executives</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/careers/life-at-deloitte.html?icid=top_life-at-deloitte" target="_self">
# <strong>Life at Deloitte</strong>
# </a>
# </div>
# <div class="no-click-close sub-menu-items ">
# <a class="no-click-close" href="/us/en/careers/alumni.html?icid=top_alumni" target="_self">
# <strong>Alumni</strong>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# </div>
# </header>
# <div id="datalayerdiv">
# <script type="text/javascript">
#         dataLayer.page={
#             "attributes": {
#                 "pageID": "d6ec5039",
#                 "pagename": "/us/en",
#                 "country": "us",
#                 "language": "en",
#                 "urlCountry": "us",
#                 "pageTemplate": "Deloitte_Member_Firm_Home_Page_Template",
#                 "secondLevel": "",
#                 "siteSection": "home",
#                 "subSection3": "",
#                 "documentAge": "0",
#                 "dateModified": "",
#                 "datePublished": "",
#                 "promoIds": "",
#                 "tagNames": "",
#                 "contentLabel18n": "",
#                 "pageTitle": "Deloitte_US",
#                 "simpleFormName": "",
#                 "successType": "",
#                 "blueprintName": "/content/www/globalblueprint/en",
#                 "originatorId": "",
#                 "headline1": "Deloitte US",
#                 "headline2": "",
# 				"featured": "",
# 				"createDate": "2017-11-09",
# 				"publishDate": "2017-11-09",
# 				"authors": "",
# 				"tag1": "",
# 				"tag2": "",
# 				"city": "",
# 				"state": "",
# 				"postalCode": "",
# 				"latitude": "",
# 				"longitude": "",
# 				"address": "",
# 				"employeeTitle": "",
# 				"tagTopic": "",
# 				"thumbnailUrl": "",
# 				"description": "Deloitte provides industry-leading audit, consulting, tax, and advisory services to many of the world’s most admired brands, including 80 percent of the Fortune 500. As a member firm of Deloitte Touche Tohmatsu Limited, a network of member firms, we are proud to be part of the largest global professional services network, serving our clients in the markets that are most important to them.",
# 				"entityName": "",
# 				"media": ""
#             }
#         };
#         dataLayer.seeMoreSection={
#         	"promoIds": ""
#         };
# 		dataLayer.discovermore={
#           "promoIds": "",
#           "tagNames": "",
#           "pageTemplate": ""
#         };
# 		dataLayer.nextsteps={
#           "promoIds": "",
#           "pageTemplate": ""
#         };
# 		dataLayer.trending={
#           "promoIds": "",
#           "pageTemplate": "Deloitte_Member_Firm_Home_Page_Template_trending"
#         };
# 		dataLayer.search={
#           "searchTerm": "",
#           "pageNum": "1",
#           "Facet": "all"
#         };
# 		dataLayer.custom={
#           "customConversion1": "",
#           "customConversion2": "",
#           "customConversion3": "",
#           "customConversion4": "",
#           "customConversion5": "",
#           "customConversion6": "",
#           "customConversion7": "",
#           "customTraffic1": "",
#           "customTraffic2": "",
#           "customTraffic3": "",
#           "customTraffic4": "",
#           "customTraffic5": "",
#           "customActions": "",
#           "targetingCodes": ""
#         };
# 		dataLayer.profile={
#           "userID": "",
#           "employeeemail": "",
#           "emplyeephone": "",
#           "employeemaplink": "",
#           "employeeprofilename":""
#         };
# 		dataLayer.careers={
#             "experienceLevel": "",
#             "jobCountry": "",
#             "jobName": "",
#             "jobRegion": "",
#             "jobSearchKeyWord": "",
#             "jobType": "",
#             "noJobResultPage": "false",
#             "changeSearch": "false"
# 		};
#     </script>
# </div>
# <div class="wrapper home-page">
# <!-- Extended Background -->
# <div class="extended-background black secondary">
# <!-- add global site selector over here -->
# <div class="showcase-frame">
# <div class="showcaseimage section">
# <!-- showcase component start here -->
# <a class="promo-focus" data-cq-id="4f77dd1c" data-promocategory="curated" data-promocontenttype="article" data-promoname="Meet Team Deloitte" data-promotype="primary" href="/us/en/pages/about-deloitte/articles/deloitte-us-olympic-committee-sponsorship.html" target="_self">
# <div class="showcaseimage section showcase-basic" id="showcase-image" style="background-image: url(/content/dam/Deloitte/us/Images/Showcase/us-elana-meyers-taylor-bobsledding.jpg)">
# <div class="showcase-content-wrap">
# <div class="showcase-basic-content fade-load" style="opacity: 0;">
# <div class="content-wrap">
# <h1>Meet Team Deloitte</h1>
# <h2 class="dot-ellipsis dot-resize-update showcase-content-height">Get to know the 11 U.S. competitors on their journey to the Olympic Winter Games PyeongChang 2018.</h2>
# <div class="reverse-btn button">Read more</div>
# </div>
# </div>
# </div>
# </div>
# </a>
# <script type="text/javascript">
#         var datalayerID = '4f77dd1c';
#         dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerID;
#   </script>
# <!-- </section> --></div>
# </div>
# </div>
# <div class="main-container home-page">
# <div class="content main">
# <div id="home-page-mobile-tabs" style="touch-action: pan-y; -webkit-user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">
# <div class="tabHeader">
# <ul class="tabbedMenu">
# <li class="tab active" data-tab="featured"><a class="label">Featured</a></li>
# <li class="tab" data-tab="trending"><a class="label">Trending</a></li>
# </ul>
# </div>
# </div>
# <div class="table-frame" id="main-featured-trending">
# <div class="table-frame-row">
# <div class="table-frame-col-70 featured" id="home-featured">
# <div class="table-frame" id="row1">
# <div class="table-frame-row">
# <!-- featured promo with 4:1 image Add class promo4x1 to promo -->
# <div class="table-frame-col-50 featuredpromo " id="home-target-1-1">
# <div class="featuredpromo section">
# <a class="promo-focus" data-contenttype="predictions" data-cq-id="2196bec" data-promocategory="curated" data-promocontenttype="article" data-promoname="Key Facts about the Deloitte Email Cyber-Incident" data-promotype="featured" href="https://www2.deloitte.com/content/dam/Deloitte/global/Documents/About-Deloitte/gx-FactsSheetforGlobalWebsite-cyber-attack.pdf" target="_blank">
# <div class="featured-promo descriptive-promo insight-white">
# <div class="article-image">
# <img alt="" data-aspectratio="4:1" data-orgsrc="/content/dam/Deloitte/global/Images/header_images/gx-cyber-pixelated-dots.jpg" src=""/>
# </div>
# <div class="article-text">
# <p class="promo-label">Fact sheet</p>
# <h2>Key Facts about the Deloitte Email Cyber-Incident</h2>
# <h3>October 6, 2017</h3>
# </div>
# </div>
# </a>
# <div class="clear"></div>
# <script type="text/javascript">
# 	 		registerCuratedPromos('2196bec', 'featured');
#          </script>
# <script type="text/javascript">
# 			var flag = 'true';
#             var datalayerpromoID = '2196bec';
#             if(flag == 'true'){
# 				dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
#             } else {
# 				dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
#             }
# 	</script>
# </div>
# </div>
# <!-- featured promo with 4:1 image Add class promo4x1 to promo -->
# <div class="table-frame-col-50 featuredpromo " id="home-target-1-2">
# <div class="featuredpromo section">
# <a class="promo-focus" data-contenttype="perspectives" data-cq-id="7fba4318" data-promocategory="curated" data-promocontenttype="article" data-promoname="Digital mobility: 2017 talent trends" data-promotype="featured" href="/us/en/pages/tax/articles/digital-mobility-talent-trends.html" target="_self">
# <div class="featured-promo descriptive-promo insight-white">
# <div class="article-image">
# <img alt="" data-aspectratio="4:1" data-orgsrc="/content/dam/Deloitte/global/Images/header_images/gx-tax-global-mobility-trends-b.jpg" src=""/>
# </div>
# <div class="article-text">
# <p class="promo-label">Perspectives</p>
# <h2>Digital mobility: 2017 talent trends</h2>
# <h3>How can you adjust for the digital age?<br/>
# </h3>
# <div class="call-to-action-label ">
# 										Read more
# 									</div>
# </div>
# </div>
# </a>
# <div class="clear"></div>
# <script type="text/javascript">
# 	 		registerCuratedPromos('7fba4318', 'featured');
#          </script>
# <script type="text/javascript">
# 			var flag = 'true';
#             var datalayerpromoID = '7fba4318';
#             if(flag == 'true'){
# 				dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
#             } else {
# 				dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
#             }
# 	</script>
# </div>
# </div>
# </div>
# </div>
# <div class="table-frame" id="row2">
# <div class="table-frame-row">
# <!-- featured promo with 1:1 image Add class promo1x1 to promo -->
# <div class="table-frame-col-100 featuredpromo " id="home-target-2-1">
# <div class="featuredpromo section">
# <a class="promo-focus" data-contenttype="analysis" data-cq-id="858d5f1f" data-promocategory="curated" data-promocontenttype="article" data-promoname="2017 holiday retail survey" data-promotype="featured" href="/us/en/pages/consumer-business/articles/holiday-retail-sales-consumer-survey.html" target="_self">
# <div class="featured-promo descriptive-promo insight-white">
# <div class="article-image">
# <img alt="" data-aspectratio="1:1" data-orgsrc="/content/dam/Deloitte/us/Images/promo_images/us-circle-promo/us-snowflake-knitted-promo.jpg" data-orgsrc1="/content/dam/Deloitte/us/Images/header_images/illustrations/us-holiday-cross-stitch-banner.jpg" src=""/>
# </div>
# <div class="article-text">
# <p class="promo-label">Analysis</p>
# <h2>2017 holiday retail survey</h2>
# <h3>An annual analysis of the peak shopping season<br/>
# </h3>
# <p class="description-short">This season, for the first time, online shopping is expected to exceed in-store and spending on experiences and self-gifting is predicted to increase.</p>
# <p class="description dot-ellipsis dot-resize-update short-desc-enabled">Deloitte's annual holiday retail survey polled more than 5,000 US consumers to determine their shopping and spending intentions for the 2017 holiday season.</p>
# <div class="call-to-action-label ">
# 										Read more
# 									</div>
# </div>
# </div>
# </a>
# <div class="clear"></div>
# <script type="text/javascript">
# 	 		registerCuratedPromos('858d5f1f', 'featured');
#          </script>
# <script type="text/javascript">
# 			var flag = 'true';
#             var datalayerpromoID = '858d5f1f';
#             if(flag == 'true'){
# 				dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
#             } else {
# 				dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
#             }
# 	</script>
# </div>
# </div>
# </div>
# </div>
# <div class="table-frame" id="row3">
# <div class="table-frame-row">
# <!--  standard promo ensure the table-frame-col-50 is added to the class -->
# <div class="table-frame-col-50 standardpromo " id="home-target-3-1">
# <div class="standardpromo section">
# <a class="promo-focus" data-contenttype="analysis" data-cq-id="acc79d1b" data-promocategory="curated" data-promocontenttype="article" data-promoname="Robotic process automation and cognitive technologies in insurance&lt;br&gt;
# " data-promotype="standard" href="/us/en/pages/operations/articles/robotic-process-automation-insurance.html" target="_self">
# <div class="standard-promo analysis-color">
# <p class="promo-label">Analysis</p>
# <h3 class="tertiary-headline">Robotic process automation and cognitive technologies in insurance<br/>
# </h3>
# <div class="page-description-for-promo">Adopting a more customer-centric approach will give insurers opportunities to unlock cognitive automation across the insurance value chain.</div>
# </div>
# </a>
# <script type="text/javascript">
# 		registerCuratedPromos('acc79d1b', 'standard');
#
# 		var flag = 'true';
# 		var datalayerpromoID = 'acc79d1b';
#             if(flag == 'true'){
# 				dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
#             } else {
# 				dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
#             }
#     </script>
# </div>
# </div>
# <!--  standard promo ensure the table-frame-col-50 is added to the class-->
# <div class="table-frame-col-50 standardpromo " id="home-target-3-2">
# <div class="eventpromo section">
# <a class="promo-focus" data-contenttype="webinars" data-cq-id="fea539df" data-promocategory="curated" data-promocontenttype="events" data-promoname="Holiday 2017: How retailers can secure customer devotion" data-promotype="standard" href="/us/en/pages/dbriefs-webcasts/events/november/2017/dbriefs-holiday-2017-how-retailers-can-secure-customer-devotion.html" target="_self">
# <div class="events-promo event-color">
# <p class="promo-label">Dbriefs Webcast</p>
# <h3 class="tertiary-headline">Holiday 2017: How retailers can secure customer devotion
# 				</h3>
# <div class="page-description-for-promo">November 15 | 11 a.m. ET | Participants will learn results of Deloitte's 32nd annual holiday survey and how a customer rapport strategy can tip the competitive war for share in their favor.</div>
# </div>
# </a>
# <div class="clear"></div>
# <script type="text/javascript">
# 		 		registerCuratedPromos('fea539df', 'events');
#
# 		 		var flag = 'true';
# 				var datalayerpromoID = 'fea539df';
# 		            if(flag == 'true'){
# 						dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
# 		            } else {
# 						dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
# 		            }
# 		</script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="table-frame-col-30 trending">
# <div class="no-display" id="home-recommended">
# <!-- recommended translation -->
# <h3>Recommended </h3>
# </div>
# <div id="home-trending">
# <h3> Trending </h3>
# <ol class="trending-list">
# </ol>
# </div>
# </div>
# </div>
# </div>
# <div class="table-frame featured">
# <div class="table-frame-row"><button class="button see-more-btn"><a aria-label="Click here to access the featured promos." href="javascript:void(0)" id="see-more">See more </a></button></div>
# </div>
# <!-- See More section -->
# <div class="table-frame layout-ctrl below-fold" id="featured-more">
# <div class="table-frame-row">
# <div class="table-frame-col-100 featured">
# <!-- Row 4 Start -->
# <div class="autowidthcolumnctrl dcom-feature-more-row-4" id="row4">
# <div class="auto-width-column">
# <div class="awc-sixtyseven-thirtythree-c0 insight-white">
# <div class="dcomparsys sixtyseven-thirtythree-c0">
# <!-- Featured 1:1 promo-->
# <div><div class="featuredpromo section">
# <a class="promo-focus" data-contenttype="analysis" data-cq-id="cc012b5b" data-promocategory="curated" data-promocontenttype="article" data-promoname="Crunch time III: The CFO's guide to cognitive technology" data-promotype="featured" href="http://deloi.tt/crunchtime" target="_blank">
# <div class="featured-promo descriptive-promo insight-white">
# <div class="article-image">
# <img alt="" data-aspectratio="1:1" data-orgsrc="/content/dam/Deloitte/us/Images/promo_images/illustrations/us-illustration-circle-watchtimer-brain-cognitive-promo.png" data-orgsrc1="/content/dam/Deloitte/us/Images/header_images/illustrations/us-illustration-circle-watchtimer-brain-cognitive.png" src=""/>
# </div>
# <div class="article-text">
# <p class="promo-label">Analysis</p>
# <h2>Crunch time III: The CFO's guide to cognitive technology</h2>
# <h3>Reimagine finance in a digital world<br/>
# </h3>
# <p class="description-short">Gain insight into how and where cognitive technologies can play a role in the finance organization.</p>
# <p class="description dot-ellipsis dot-resize-update short-desc-enabled">Explore the latest report, “Crunch time III,” in which we provide insight into how and where cognitive technologies can play a role in the finance organization.</p>
# <div class="call-to-action-label ">
# 										Read more
# 									</div>
# </div>
# </div>
# </a>
# <div class="clear"></div>
# <script type="text/javascript">
# 	 		registerCuratedPromos('cc012b5b', 'featured');
#          </script>
# <script type="text/javascript">
# 			var flag = 'false';
#             var datalayerpromoID = 'cc012b5b';
#             if(flag == 'true'){
# 				dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
#             } else {
# 				dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
#             }
# 	</script>
# </div>
# </div>
# </div>
# </div>
# <div class="awc-sixtyseven-thirtythree-c1 ">
# <div class="dcomparsys sixtyseven-thirtythree-c1">
# <!-- Standard/Featured 4:1/CTA promo-->
# <div><div class="standardpromo section">
# <a class="promo-focus" data-contenttype="analysis" data-cq-id="4d5b2b30" data-promocategory="curated" data-promocontenttype="article" data-promoname="Is your organization moving towards digital maturity?&lt;br&gt;
# " data-promotype="standard" href="http://deloi.tt/mitsurvey" target="_blank">
# <div class="standard-promo analysis-color">
# <p class="promo-label">Analysis</p>
# <h3 class="tertiary-headline">Is your organization moving towards digital maturity?<br/>
# </h3>
# <div class="page-description-for-promo">Join MIT SMR and Deloitte Digital as we begin our seventh annual research collaboration with a survey on the evolution of the digital organization.</div>
# </div>
# </a>
# <script type="text/javascript">
# 		registerCuratedPromos('4d5b2b30', 'standard');
#
# 		var flag = 'false';
# 		var datalayerpromoID = '4d5b2b30';
#             if(flag == 'true'){
# 				dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
#             } else {
# 				dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
#             }
#     </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="autowidthcolumnctrl dcom-feature-more-row-5" id="row5">
# <div class="auto-width-column">
# <div class="awc-three-thirtythree-c0 insight-white ">
# <div class="three-thirtythree-c0 dcomparsys">
# <!-- Standard/Featured 4:1 promo-->
# <div><div class="dupressfeaturedpromo section">
# <a class="promo-focus" data-contenttype="Deloitte Insights" data-cq-id="5a54ca6e" data-promocategory="curated" data-promocontenttype="dupromo" data-promoname="More real than reality: Transforming work through augmented reality" data-promotype="featured" href="https://dupress.deloitte.com/dup-us-en/deloitte-review/issue-21/augmented-reality-at-workplace.html?icid=dcom_promo_featured|us;en" target="_blank">
# <div class="du-featured-promo featured-promo descriptive-promo insight-white">
# <div class="article-image">
# ...
#
# 	 		var flag = 'false';
# 			var datalayerpromoID = '5aef3d0e';
# 	            if(flag == 'true'){
# 					dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
# 	            } else {
# 					dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
# 	            }
#          </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="autowidthcolumnctrl dcom-feature-more-row-8" id="row8">
# <div class="auto-width-column">
# <div class="awc-sixtyseven-thirtythree-c0 insight-white">
# <div class="dcomparsys sixtyseven-thirtythree-c0">
# <!-- Featured 1:1 promo-->
# <div><div class="featuredpromo section">
# <a class="promo-focus" data-contenttype="analysis" data-cq-id="ada1f757" data-promocategory="curated" data-promocontenttype="article" data-promoname="Millennials in the workplace: Myth meets reality" data-promotype="featured" href="/us/en/pages/consulting/articles/millennials-and-workstyles.html" target="_self">
# <div class="featured-promo descriptive-promo insight-white">
# <div class="article-image">
# <img alt="" data-aspectratio="1:1" data-orgsrc="/content/dam/Deloitte/us/Images/promo_images/business-finance/us-millennials-promo.png" data-orgsrc1="/content/dam/Deloitte/us/Images/header_images/business-finance/us-bc-leaders.png" src=""/>
# </div>
# <div class="article-text">
# <p class="promo-label">Analysis</p>
# <h2>Millennials in the workplace: Myth meets reality</h2>
# <h3>Business Chemistry® research unlocks the mindset of millennials</h3>
# <p class="description-short">New research from Deloitte's Business Chemistry reveals noteworthy millennial work styles and generational differences.</p>
# <p class="description dot-ellipsis dot-resize-update short-desc-enabled">New research from Deloitte's Business Chemistry reveals noteworthy millennial work styles, identifying differences between Gen Y, Gen X, and baby boomers.</p>
# <div class="call-to-action-label ">
# 										Read more
# 									</div>
# </div>
# </div>
# </a>
# <div class="clear"></div>
# <script type="text/javascript">
# 	 		registerCuratedPromos('ada1f757', 'featured');
#          </script>
# <script type="text/javascript">
# 			var flag = 'false';
#             var datalayerpromoID = 'ada1f757';
#             if(flag == 'true'){
# 				dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
#             } else {
# 				dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
#             }
# 	</script>
# </div>
# </div>
# </div>
# </div>
# <div class="awc-sixtyseven-thirtythree-c1 ">
# <div class="dcomparsys sixtyseven-thirtythree-c1">
# <!-- Standard/Featured 4:1/CTA promo-->
# <div><div class="standardpromo section">
# <a class="promo-focus" data-contenttype="analysis" data-cq-id="1647f5d7" data-promocategory="curated" data-promocontenttype="article" data-promoname="Deloitte 2017 survey of US health system CEOs&lt;br&gt;
# " data-promotype="standard" href="/us/en/pages/life-sciences-and-health-care/articles/health-system-ceos.html" target="_self">
# <div class="standard-promo analysis-color">
# <p class="promo-label">Analysis</p>
# <h3 class="tertiary-headline">Deloitte 2017 survey of US health system CEOs<br/>
# </h3>
# <div class="page-description-for-promo">A May 2017 survey of 20 hospital chief executive officers (CEOs) found these top concerns: future of Medicaid, transition to value-based care, declining margins, and technology.</div>
# </div>
# </a>
# <script type="text/javascript">
# 		registerCuratedPromos('1647f5d7', 'standard');
#
# 		var flag = 'false';
# 		var datalayerpromoID = '1647f5d7';
#             if(flag == 'true'){
# 				dataLayer.page.attributes.promoIds = dataLayer.page.attributes.promoIds + "," + datalayerpromoID;
#             } else {
# 				dataLayer.seeMoreSection.promoIds = dataLayer.seeMoreSection.promoIds + "," + datalayerpromoID;
#             }
#     </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- See More Section Ends -->
# </div>
# </div>
# <script>
# 	var title_dataLayer = 'Home';
#     	if(typeof dataLayer != 'undefined'){
# 		dataLayer.page.attributes.entityName = title_dataLayer;
# 	}
#
#   </script></div>
# <footer id="footer-section">
# <div class="footer-CTA three-links">
# <ul>
# <li><a href="/us/en/footerlinks/contact-us.html?icid=bn_contact-us" target="_self">Contact us</a></li>
# <li><a href="http://jobs2.deloitte.com?icid=bn_job-search" target="_blank">Search jobs</a></li>
# <li><a href="/us/en/footerlinks/submit-rfp.html?icid=bn_submit-rfp" target="_self">Submit RFP</a></li>
# </ul>
# </div>
# <div class="footer-wrapper">
# <div class="footer-container" role="navigation">
# <div class="footerlinks">
# <div class="footer-column first" id="footer-col1">
# <p class="tertiary-headline">Get Connected</p>
# <ul class="footer-col">
# <li><a href="/us/en.html?icid=bottom_us-homepage-redirect">
# 									Home
# 									</a></li>
# <li><a href="http://dupress.deloitte.com/?icid=bottom_dup" target="_blank">
# 									Deloitte Insights
# 									</a></li>
# <li><a class="press" href="/us/en/footerlinks/pressreleasespage.html?icid=bottom_pressreleasespage&amp;q=*&amp;sp_x_18=content-type&amp;sp_s=date-published%7Ctitle&amp;sp_q_18=%22Press+releases%22">
# 								Press releases
# 								</a></li>
# <li><a href="/us/en/footerlinks/social-media.html?icid=bottom_social-media">
# 									Social media
# 									</a></li>
# <li><a href="/us/en/careers/alumni.html?icid=bottom_alumni">
# 									Alumni
# 									</a></li>
# <li><a href="https://my.deloitte.com/" target="_blank">
# 									Email subscriptions
# 									</a></li>
# <li><a href="/us/en/footerlinks/submit-rfp.html?icid=bottom_submit-rfp">
# 									Submit RFP
# 									</a></li>
# <li><a href="/us/en/footerlinks/office-locator.html?icid=bottom_office-locator">
# 									US office locations
# 									</a></li>
# <li><a href="/us/en/footerlinks/global-office-directory.html?icid=bottom_global-office-directory">
# 									Global office directory
# 									</a></li>
# <li><a href="/us/en/footerlinks/newsroom.html?icid=bottom_newsroom">
# 									Newsroom
# 									</a></li>
# <li><a class="press" href="/us/en/footerlinks/crg-profiles.html?icid=bottom_crg-profiles&amp;q=*&amp;sp_x_18=content-type&amp;sp_s=date-published%7Ctitle&amp;sp_q_18=%22Press+releases%22">
# 								CRG profiles
# 								</a></li>
# <li><a class="press" href="/us/en/footerlinks/recentlypublished.html?icid=bottom_recentlypublished&amp;q=*&amp;sp_x_18=content-type&amp;sp_s=date-published%7Ctitle&amp;sp_q_18=%22Press+releases%22">
# 								Recently Published
# 								</a></li>
# <li><a href="/us/en/footerlinks/about-us-deloitte.html?icid=bottom_about-us-deloitte">
# 									About us
# 									</a></li>
# <li><a class="contact-us" href="/us/en/footerlinks/contact-us.html?icid=bottom_contact-us">
# 									Contact us
# 									</a></li>
# </ul>
# </div>
# <div class="footer-column" id="footer-col2">
# <p class="tertiary-headline">Services</p>
# <ul class="footer-col">
# <li><a href="/us/en/services/advisory.html?icid=bottom_advisory">
# 									Risk and Financial Advisory
# 									</a></li>
# <li><a href="/us/en/services/audit.html?icid=bottom_audit">
# 									Audit &amp; Assurance
# 									</a></li>
# <li><a href="/us/en/services/consulting.html?icid=bottom_consulting">
# 									Consulting
# 									</a></li>
# <li><a href="/us/en/services/mergers-and-acquisitions.html?icid=bottom_mergers-and-acquisitions">
# 									Mergers &amp; Acquisitions
# 									</a></li>
# <li><a href="/us/en/services/tax.html?icid=bottom_tax">
# 									Tax
# 									</a></li>
# <li><a href="/us/en/services/deloitte-growth-enterprise-services.html?icid=bottom_deloitte-growth-enterprise-services">
# 									Deloitte Growth Enterprise Services
# 									</a></li>
# </ul>
# </div>
# <div class="footer-column" id="footer-col3">
# <p class="tertiary-headline">Industries</p>
# <ul class="footer-col">
# <li><a href="/us/en/industries/consumer-industrial-products.html?icid=bottom_consumer-industrial-products">
# 									Consumer &amp; Industrial Products
# 									</a></li>
# <li><a href="/us/en/industries/energy-and-resources.html?icid=bottom_energy-and-resources">
# 									Energy &amp; Resources
# 									</a></li>
# <li><a href="/us/en/industries/financial-services.html?icid=bottom_financial-services">
# 									Financial Services
# 									</a></li>
# <li><a href="/us/en/industries/life-sciences-and-health-care.html?icid=bottom_life-sciences-and-health-care">
# 									Life Sciences &amp; Health Care
# 									</a></li>
# <li><a href="/us/en/industries/manufacturing.html?icid=bottom_manufacturing">
# 									Manufacturing
# 									</a></li>
# <li><a href="/us/en/industries/public-sector.html?icid=bottom_public-sector">
# 									Public Sector
# 									</a></li>
# <li><a href="/us/en/industries/real-estate.html?icid=bottom_real-estate">
# 									Real Estate &amp; Construction
# 									</a></li>
# <li><a href="/us/en/industries/technology-media-and-telecommunications.html?icid=bottom_technology-media-and-telecommunications">
# 									Technology, Media &amp; Telecommunications
# 									</a></li>
# <li><a href="/us/en/industries/all-industries-sectors.html?icid=bottom_all-industries-sectors">
# 									All Industries and Sectors
# 									</a></li>
# </ul>
# </div>
# <div class="footer-column" id="footer-col4">
# <p class="tertiary-headline">Careers</p>
# <ul class="footer-col">
# <li><a href="http://jobs2.deloitte.com?icid=bottom_job-search" target="_blank">
# 									Job search
# 									</a></li>
# <li><a href="/us/en/pages/labor-condition-applications/articles/labor-condition-applications.html?icid=bottom_labor-condition-applications">
# 									Labor Condition Applications
# 									</a></li>
# <li><a href="/us/en/pages/careers/articles/join-deloitte-assistance-for-disabled-applicants.html?icid=bottom_assistance-for-disabled-applicants">
# 									Assistance for Disabled Applicants
# 									</a></li>
# <li><a href="/us/en/pages/careers/articles/eeo-affirmative-action-documents.html/us/en/pages/careers/articles/eeo-affirmative-action-documents.html?icid=bottom_eeo-policy-statement" target="_blank">
# 									EEO/Affirmative Action Documents
# 									</a></li>
# <li><a href="/us/en/pages/careers/articles/ban-the-box-notices.html?icid=bottom_ban-the-box" target="_blank">
# 									Ban the Box Notices
# 									</a></li>
# <li><a href="/us/en/careers/students.html?icid=bottom_students">
# 									Students
# 									</a></li>
# <li><a href="/us/en/careers/experienced-hires.html?icid=bottom_experienced-hires">
# 									Experienced hires
# 									</a></li>
# <li><a href="/us/en/careers/executives.html?icid=bottom_executives">
# 									Executives
# 									</a></li>
# <li><a href="/us/en/careers/life-at-deloitte.html?icid=bottom_life-at-deloitte">
# 									Life at Deloitte
# 									</a></li>
# <li><a href="/us/en/careers/alumni.html?icid=bottom_alumni">
# 									Alumni
# 									</a></li>
# </ul>
# </div>
# <div class="footer-column" id="footer-col5">
# <p class="tertiary-headline">Legal</p>
# <ul class="footer-col">
# <li><a href="/us/en/pages/about-deloitte/articles/about-deloitte.html?icid=bottom_about-deloitte">
# 									About Deloitte
# 									</a></li>
# <li><a href="/us/en/footerlinks1/terms-of-use.html?icid=bottom_terms-of-use">
# 									Terms of use
# 									</a></li>
# <li><a href="/us/en/footerlinks1/privacy.html?icid=bottom_privacy">
# 									Privacy
# 									</a></li>
# <li><a href="/us/en/footerlinks1/privacy-shield.html?icid=bottom_privacy-shield">
# 									Privacy shield
# 									</a></li>
# <li><a href="/us/en/footerlinks1/cookies.html?icid=bottom_cookies">
# 									Cookies
# 									</a></li>
# <li><a href="/us/en/footerlinks1/privacy-tss.html?icid=bottom_privacy-tss">
# 									Privacy TSS
# 									</a></li>
# </ul>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="disclaimer-text custom-rte" id="footer-disclaimer" role="contentinfo">
# <p>© 2017. See <a href="/us/en/legal/terms-of-use.html">Terms of Use</a> for more information.</p>
# <p>Deloitte refers to one or more of Deloitte Touche Tohmatsu Limited, a UK private company limited by guarantee ("DTTL"), its network of member firms, and their related entities. DTTL and each of its member firms are legally separate and independent entities. DTTL (also referred to as "Deloitte Global") does not provide services to clients. In the United States, Deloitte refers to one or more of the US member firms of DTTL, their related entities that operate using the "Deloitte" name in the United States and their respective affiliates. Certain services may not be available to attest clients under the rules and regulations of public accounting. Please see <a href="/us/en/pages/about-deloitte/articles/about-deloitte.html">www.deloitte.com/about</a> to learn more about our global network of member firms.</p>
# </div>
# <div class="social-tab">
# <div class="social-media-links" id="footer-social">
# <ul>
# <li><a class="icon-facebook" href="https://www.facebook.com/DeloitteUS" title="Like Deloitte US on Facebook"></a></li>
# <li><a class="icon-twitter" href="https://www.twitter.com/deloitteus" title="Follow Deloitte US on Twitter"></a></li>
# <li><a class="icon-linkedin" href="https://www.linkedin.com/company/1038" title="Connect with Deloitte on LinkedIn"></a></li>
# <li><a class="icon-youtube" href="https://www.youtube.com/user/DeloitteLLP" title="View Deloitte US on YouTube"></a></li>
# <li><a class="icon-glassdoor" href="http://www.glassdoor.com/Overview/Working-at-Deloitte-EI_IE2763.11,19.htm" title="Check Deloitte US out on Glassdoor"></a></li>
# <li><a class="icon-instagram" href="https://www.instagram.com/lifeatdeloitteus/" title="Follow Deloitte US on Instagram"></a></li>
# </ul>
# </div>
# <div class="sponsor-logo">
# <a href="/us/en/pages/about-deloitte/articles/about-deloitte-team-usa-olympic-sponsorship-pro-bono-services.html">
# <img alt="Learn more about Deloitte's work for the US Olympic Committee" height="101" src="/content/dam/Deloitte/us/Images/Misc/usoc-logo-02092017.png" width="391"/>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <div class="cookiesOverlayComponent cookies"><script>
# var buttonText = 'Accept and close';
# var cookieLabel = "Cookie notice";
# </script>
# </div>
# <!-- adobeproduspub16.2.0.SP1-CFP1 -->
# <script src="/etc/designs/dcom/dcom-main-footer.min.1407171800.js" type="text/javascript"></script>
# <div class="servicecomponents cloudservices"><div class="cloudservice generictracker"><script type="text/javascript">
#     //Start - Google Tag Manager
# </script>
# </div>
# </div>
# <script>
# (function(w, d, s, l, i) {
#   w[l] = w[l] || [];
#   w[l].push({
# 	'gtm.start': new Date().getTime(),
# 	event: 'gtm.js'
#   });
#   var f = d.getElementsByTagName(s)[0],
# 	j = d.createElement(s),
# 	dl = l != 'dataLayer' ? '&l=' + l : '';
#   j.async = true;
#   j.src =
# 	'//www.googletagmanager.com/gtm.js?id=' + i + dl;
#   f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'psDelDataLayer', 'GTM-MM36PB'); </script>
# <div class="servicecomponents cloudservices">
# <div class="cloudservice generictracker">
# <script>
#   //End - Google Tag Manager
#
# //start CRG Profiles S&P results page
# $(function() {
#   var loc = window.location.href;
#   if (/footerlinks\/crg\-profiles/.test(loc)) {
# 	$(".primary-headline").text("Deloitte CRG Profiles");
# 	$(".page-intro-copy").hide();
# 	$(".release-date").hide();
# 	$(".body-copy").hide();
#   }
# });
# //end CRG Profiles S&P results page
#
# //start Ambassador Program S&P results page
# $(function() {
#   var loc = window.location.href;
#   if (/footerlinks\/recentlypublished/.test(loc)) {
# 	$(".primary-headline").text("Recently published");
#  }
# });
# //end Ambassador Program S&P results page</script></div>
# <script type="text/javascript">_satellite.pageBottom();</script></div>
# <script>
# $(document.body).on("pageReady",function(event, y, z){
#
# 	console.log(event.type);
#
# });
# //Finally, register a Page Load callback and call the execute method on JQuery Page Load event.
# 	$(function() {
#
# 		var executeDeferred = pageLoadFramework.executePageLoadEvents();
#
# 		//The execute method returns a deferred.  So, if something needs to wait for it, this is how you do it.
# 		executeDeferred.done(function(){
#
#
# 		});
# 	});
#
# </script>
# </body>
# </html>

# %% [markdown]
# ### Example HTML
#
# Before we explore the full HMTL, let's work with some example HTML

# %%
example_html = """
    <!DOCTYPE html>
    <html lang='en'>

    <head>
        <title>The ML Guild</title>
    </head>

    <body>
        <h1 id='headline'>Machine Learning Guild Overview</h1>
            <p class='description' >The ML guild provides rich learning 
            content around machine learning, including self-guided courses, 
            curriculum-based learning programs, and mentorship by more 
            advanced practitioners</p>
        <h2>Courses</h2>

        <p>Below are the ML Guild Tracks:</p>

        <ul>
            <li class='first'>Explorer</li>
            <li class='second'>Apprentice</li>
            <li class='third'>Master</li>
        </ul>
    </body>

    </html>
    """

# %% [markdown]
# ### Common BeautifulSoup Syntax
#
# #### Methods
# - find: find only the first specified html tag that meets a specified condition
# - find_all: find all html tags that meets a specified condition
#
# #### Parameters
# - attrs: dict of attributes (e.g. id, class) to filter relevant html
#
# #### Attributes
# - text: only view the text in the html (ignore the html itself)

# %%
# Beautiful Soup supports the HTML parser included in Python’s standard library, 
# but it also supports a number of third-party Python parsers. 
# One is the lxml parser, which is fast and lenient (i.e. it will not crash it the html is not formatted correctly)

b = BeautifulSoup(example_html, 'lxml')
b
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>The ML Guild</title>
# </head>
# <body>
# <h1 id="headline">Machine Learning Guild Overview</h1>
# <p class="description">The ML guild provides rich learning
#             content around machine learning, including self-guided courses,
#             curriculum-based learning programs, and mentorship by more
#             advanced practitioners</p>
# <h2>Courses</h2>
# <p>Below are the ML Guild Tracks:</p>
# <ul>
# <li class="first">Explorer</li>
# <li class="second">Apprentice</li>
# <li class="third">Master</li>
# </ul>
# </body>
# </html>

# %% [markdown]
# #### find

# %%
b.find('title')
# Out:
# <title>The ML Guild</title>

# %%
b.find('h2')
# Out:
# <h2>Courses</h2>

# %% [markdown]
# #### text

# %%
b.find('title').text
# Out:
# 'The ML Guild'

# %%
b.find('h2').text
# Out:
# 'Courses'

# %%
b.find('li').text
# Out:
# 'Explorer'

# %% [markdown]
# #### find_all

# %%
b.find_all('p')
# Out:
# [<p class="description">The ML guild provides rich learning
#              content around machine learning, including self-guided courses,
#              curriculum-based learning programs, and mentorship by more
#              advanced practitioners</p>, <p>Below are the ML Guild Tracks:</p>]

# %%
# find_all
b.find_all('li')
# Out:
# [<li class="first">Explorer</li>,
#  <li class="second">Apprentice</li>,
#  <li class="third">Master</li>]

# %%
lists = b.find_all('li')
for l in lists:
    print(l.text)
# Out:
# Explorer
# Apprentice
# Master

# %% [markdown]
# #### attrs

# %%
b.find('h1', attrs={'id':'headline'})
# Out:
# <h1 id="headline">Machine Learning Guild Overview</h1>

# %%
b.find('li', attrs={'class':'first'})
# Out:
# <li class="first">Explorer</li>

# %%
b.find('li', attrs={'class':'second'})
# Out:
# <li class="second">Apprentice</li>

# %%
b.find('li', attrs={'class':'third'})
# Out:
# <li class="third">Master</li>

# %% [markdown]
# ### Exercise

# %% [markdown]
# ### Extract articles from Deloitte.com

# %%
# read in the html from deloitte
b = BeautifulSoup(r.text, 'lxml')

# %%
articles = b.find_all('div', attrs={'class':'table-frame-col-50 standardpromo '})
for article in articles:
    title = article.find('h3', attrs={'class':'tertiary-headline'}).text
    print(title)
# Out:
# Robotic process automation and cognitive technologies in insurance
#
# Holiday 2017: How retailers can secure customer devotion

# %%
for article in articles:
    text = article.find('div', attrs={'class':'page-description-for-promo'}).text
    print(text)
# Out:
# Adopting a more customer-centric approach will give insurers opportunities to unlock cognitive automation across the insurance value chain.
# November 15 | 11 a.m. ET | Participants will learn results of Deloitte's 32nd annual holiday survey and how a customer rapport strategy can tip the competitive war for share in their favor.

# %% [markdown]
# ### Store Data
#
# We will use a common python data stucture (e.g. list or dict) to store the data for later use.
#
# Below is a common data collection pattern:
# - A. set an empty data structure to store data
# - B. iterate through an existing data set container
# - C. extract selected pieces of information, disregard the rest of the data
# - D. add the selected information to the created data structure
# - E. view results

# %%
all_headlines = []  # A 

for article in articles: # B
    headline = article.find('h3', attrs={'class':'tertiary-headline'}).text  # C
    all_headlines.append(headline)  # D

all_headlines  # E
# Out:
# ['Robotic process automation and cognitive technologies in insurance\n',
#  'Holiday 2017: How retailers can secure customer devotion\n\t\t\t\t']

# %% [markdown]
# #### Python string methods
#
# Depending on the article headlines on Deloitte.com from the day the above code was run, there likely may be newline \n and/or tabs \t at the end of the headline. These are excess characters that we do not want to store.
#
# Python string methods will allow us to handle these data quality issues.

# %%
# all headlines in a list, we slice to view the first element stored at index 0
all_headlines[0]
# Out:
# 'Robotic process automation and cognitive technologies in insurance\n'

# %%
# strip will remove all excess characters (e.g. spaces, tabs, new lines) 
# from the start and end of a string
all_headlines[0].strip()
# Out:
# 'Robotic process automation and cognitive technologies in insurance'

# %%
# replace will replace a select character (new lines below) 
# with another string of our choosing 
all_headlines[0].replace('\n', '')
# Out:
# 'Robotic process automation and cognitive technologies in insurance'

# %%
all_headlines = []

for article in articles:
    # strip the extra spaces at the start and end of the text
    headline = article.find('h3', attrs={'class':'tertiary-headline'}).text.strip()
    all_headlines.append(headline)

all_headlines
# Out:
# ['Robotic process automation and cognitive technologies in insurance',
#  'Holiday 2017: How retailers can secure customer devotion']

# %% [markdown]
# #### Exercise

# %%
# Identify, extract, and store the text of each article

all_text = []

for article in articles:
    text = article.find('div', attrs={'class':'page-description-for-promo'}).text
    all_text.append(text)

all_text
# Out:
# ['Adopting a more customer-centric approach will give insurers opportunities to unlock cognitive automation across the insurance value chain.',
#  "November 15 | 11 a.m. ET | Participants will learn results of Deloitte's 32nd annual holiday survey and how a customer rapport strategy can tip the competitive war for share in their favor."]

# %%
# Identify, extract, and store the headline and text of each article
# store them in a list called all_articles

all_articles = []

for article in articles:
    title = article.find('h3', attrs={'class':'tertiary-headline'}).text.strip()
    text = article.find('div', attrs={'class':'page-description-for-promo'}).text.strip()
    all_articles.append([title, text])

all_articles
# Out:
# [['Robotic process automation and cognitive technologies in insurance',
#   'Adopting a more customer-centric approach will give insurers opportunities to unlock cognitive automation across the insurance value chain.'],
#  ['Holiday 2017: How retailers can secure customer devotion',
#   "November 15 | 11 a.m. ET | Participants will learn results of Deloitte's 32nd annual holiday survey and how a customer rapport strategy can tip the competitive war for share in their favor."]]

# %%
# Identify, extract, and store the headline and text of each article
# store them in a dict called articles_map

articles_map = {}

for article in articles:
    title = article.find('h3', attrs={'class':'tertiary-headline'}).text.strip()
    text = article.find('div', attrs={'class':'page-description-for-promo'}).text.strip()

    articles_map[title] = text

articles_map
# Out:
# {'Holiday 2017: How retailers can secure customer devotion': "November 15 | 11 a.m. ET | Participants will learn results of Deloitte's 32nd annual holiday survey and how a customer rapport strategy can tip the competitive war for share in their favor.",
#  'Robotic process automation and cognitive technologies in insurance': 'Adopting a more customer-centric approach will give insurers opportunities to unlock cognitive automation across the insurance value chain.'}

# %%
### Try - Except
    try:
        report_name = report.find('a')['href']
    except TypeError:
        continue


### Context Manager
    # export pdf locally
    filepath = output_paths[url]
    with open(filepath, 'wb') as f:
        f.write(r.content)

    # required delay, stated in the robots.txt
    time.sleep(10)  # ten seconds
