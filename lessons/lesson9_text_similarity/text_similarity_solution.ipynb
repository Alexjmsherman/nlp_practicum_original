# %% [markdown]
# # Text Similarity
#
#
#  A common reason for such a charade is that we want to determine **similarity between pairs of documents**, or the **similarity between a specific document** and a set of other documents (such as a user query vs. indexed documents).
#
# SOURCES: http://localhost:8888/notebooks/Similarity_Queries.ipynb
#
# https://radimrehurek.com/topic_modeling_tutorial/3%20-%20Indexing%20and%20Retrieval.html

# %%
from IPython.core.display import display, HTML
from gensim import corpora, models, similarities

GENSIM_DICTIONARY_PATH = '../../raw_data/gensim/airline_dict.dict'
GENSIM_CORPUS_PATH = '../../raw_data/gensim/airline.mm'
SIMILARITY_INDEX = '../../raw_data/gensim/airline.index'
AIRLINE_CLEANED_TEXT_PATH = '../../raw_data/gensim/airline_cleaned_text.txt'

# %% [markdown]
# ### Review Cleaned Text

# %%
with open(AIRLINE_CLEANED_TEXT_PATH, 'rb') as f:
    cleaned_text = [line.decode('utf-8').strip() for line in f.readlines()]
    
import pandas as pd
pd.set_option('display.max_colwidth',200)
pd.DataFrame(cleaned_text)
# Out:
#                                                                                                                                                                                                           0
# 0                                                                                                                                no show policy fund apply future travel southwest change fee future_travel
# 1                   for example company transfarencysm campaign emphasize southwest approach treat customer fairly honestly respectfully low fare unexpected bag fee change fee hidden fee low_fare bag_fee
# 2                   for example company transfarencysm campaign emphasize southwest approach treat customer fairly honestly respectfully low fare unexpected bag fee change fee hidden fee low_fare bag_fee
# 3                                                                     the campaign highlight importance southwest customer service show southwest understand plan change charge change fee customer_service
# 4                                                                                                                       while customer pay difference airfare customer charge change fee difference airfare
# 5   the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 6   the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 7   the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 8                                                                                                                           in december congress enact statute index immigration custom fee inflation begin
# 9   finally department agriculture animal plant health inspection service publish final regulation october modify international agriculture inspection fee the_U.S._Department Plant_Health_Inspection_S...
# 10                                                                                                               under rule effective december passenger agriculture inspection fee commercial aircraft fee
# 11                                                                                                               under rule effective december passenger agriculture inspection fee commercial aircraft fee
# 12                                                                                            when occur airport cost allocate few number total flight result increase landing fee cost company landing_fee
# 13                                                                         ground facilities services southwest lease pay usage fee terminal passenger service facility airport serve leasehold improvement
# 14  the complaint allege thing airtran attempt monopolize air travel violation section sherman act conspire delta impose bag fee item check luggage violation section sherman act the_Sherman_Act Sectio...
# 15             in addition treble damage baggage fee pay airtran delta consolidated amended complaint seek injunctive relief broad range allege anticompetitive activity fee Consolidated_Amended_Complaint
# 16             in addition treble damage baggage fee pay airtran delta consolidated amended complaint seek injunctive relief broad range allege anticompetitive activity fee Consolidated_Amended_Complaint
# 17       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 18                                                             on july court grant motion certify class person pay bag fee airtran delta december november date airtran stop charge bag fee bag_fee bag_fee
# 19                                                                                                                                                  -PRON- seek treble damage injunctive relief fee expense
# 20        the plaintiff remain complaint generally seek damage include punitive damage certain case prejudgment interest disgorgement benefit accrue defendant result allegation injunctive relief fee cost
# 21                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 22                                                                                    landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 23  on asm basis landing fee rental expense decrease percent compare dollar increase offset percent increase capacity asm_basis landing_fee rental_expense decrease_percent compare_with_as_the_dollar i...
# 24                                                               the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 25                               aircraft rental landing fee rental depreciation amortization acquisition integration aircraft_rental landing_fee depreciation_and_amortization acquisition_and_integration
# 26                                                                                    landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 27  on asm basis landing fee rental expense decrease percent compare dollar increase offset percent increase capacity asm_basis landing_fee rental_expense decrease_percent compare_with_as_the_dollar i...
# 28  on dollar basis increase equally attributable high personnel expense associate travel cost company flight crew credit card fee pay party associate increase passenger revenue dollar_basis expense_a...
# 29  aircraft rental landing fee rental depreciation amortization acquisition integration other operating expense total operating expense operating income other expenses income 938__Acquisition aircraf...
# 30                                                                       amount collect passenger ancillary service fee generally recognize other revenue service provide typically flight date flight_date
# 31  for aircraft operating lease terminal operation lease expense record straight line basis include aircraft rental landing fee rental respectively consolidated statement income operating_lease strai...

# %% [markdown]
# ### Similarity
#
# spaCy is able to compare two objects, and make a prediction of how similar they are. Predicting similarity is useful for building recommendation systems or flagging duplicates. For example, you can suggest a user content that's similar to what they're currently looking at, or label a support ticket as a duplicate if it's very similar to an already existing one.
#
# ### Use cases:
# - grant similarity
# - complaint similarity

# %%
import spacy
nlp = spacy.load('en')

# %%
docs = []
# use set to avoid looking at the similarity of dupliate sentences
for sentence in set(cleaned_text):  
    docs.append(nlp(sentence))

# %%
for doc in docs[0:3]:
    print(doc)
    print()
# Out:
# amount collect passenger ancillary service fee generally recognize other revenue service provide typically flight date flight_date
#
# ground facilities services southwest lease pay usage fee terminal passenger service facility airport serve leasehold improvement
#
# for example company transfarencysm campaign emphasize southwest approach treat customer fairly honestly respectfully low fare unexpected bag fee change fee hidden fee low_fare bag_fee

# %%
docs[0].similarity(docs[1])
# Out:
# 0.89762920514640776

# %%
similarity_scores = []
for doc1 in docs:
    for doc2 in docs:
        if doc1.text != doc2.text:
            similarity_scores.append(
                [doc1.text, doc2.text, doc1.similarity(doc2)])

df = pd.DataFrame(similarity_scores, columns=['doc1','doc2','similarity'])
df.sort_values('similarity', ascending=False)
# Out:
#                                                                                                                                                                                                         doc1  \
# 506  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 169  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 623  the complaint allege thing airtran attempt monopolize air travel violation section sherman act conspire delta impose bag fee item check luggage violation section sherman act the_Sherman_Act Sectio...
# 598       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 384                               aircraft rental landing fee rental depreciation amortization acquisition integration aircraft_rental landing_fee depreciation_and_amortization acquisition_and_integration
# 239                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 497                                                             on july court grant motion certify class person pay bag fee airtran delta december november date airtran stop charge bag fee bag_fee bag_fee
# 594       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 517  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 444                                                                    the campaign highlight importance southwest customer service show southwest understand plan change charge change fee customer_service
# 617  the complaint allege thing airtran attempt monopolize air travel violation section sherman act conspire delta impose bag fee item check luggage violation section sherman act the_Sherman_Act Sectio...
# 448                                                                    the campaign highlight importance southwest customer service show southwest understand plan change charge change fee customer_service
# 631  on dollar basis increase equally attributable high personnel expense associate travel cost company flight crew credit card fee pay party associate increase passenger revenue dollar_basis expense_a...
# 174  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 166  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 431                                                                    the campaign highlight importance southwest customer service show southwest understand plan change charge change fee customer_service
# 522  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 595       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 383                               aircraft rental landing fee rental depreciation amortization acquisition integration aircraft_rental landing_fee depreciation_and_amortization acquisition_and_integration
# 214  aircraft rental landing fee rental depreciation amortization acquisition integration other operating expense total operating expense operating income other expenses income 938__Acquisition aircraf...
# 620  the complaint allege thing airtran attempt monopolize air travel violation section sherman act conspire delta impose bag fee item check luggage violation section sherman act the_Sherman_Act Sectio...
# 523  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 317  for aircraft operating lease terminal operation lease expense record straight line basis include aircraft rental landing fee rental respectively consolidated statement income operating_lease strai...
# 462  on asm basis landing fee rental expense decrease percent compare dollar increase offset percent increase capacity asm_basis landing_fee rental_expense decrease_percent compare_with_as_the_dollar i...
# 581       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 172  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 55                   for example company transfarencysm campaign emphasize southwest approach treat customer fairly honestly respectfully low fare unexpected bag fee change fee hidden fee low_fare bag_fee
# 152  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 645  on dollar basis increase equally attributable high personnel expense associate travel cost company flight crew credit card fee pay party associate increase passenger revenue dollar_basis expense_a...
# 524  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# ..                                                                                                                                                                                                       ...
# 227                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 58                   for example company transfarencysm campaign emphasize southwest approach treat customer fairly honestly respectfully low fare unexpected bag fee change fee hidden fee low_fare bag_fee
# 334        the plaintiff remain complaint generally seek damage include punitive damage certain case prejudgment interest disgorgement benefit accrue defendant result allegation injunctive relief fee cost
# 237                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 108                                                                                                                      while customer pay difference airfare customer charge change fee difference airfare
# 229                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 45                                                                          ground facilities services southwest lease pay usage fee terminal passenger service facility airport serve leasehold improvement
# 526                                                                                    landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 120                                                                                                                      while customer pay difference airfare customer charge change fee difference airfare
# 529                                                                                    landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 126                                                               the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 29                                                                          ground facilities services southwest lease pay usage fee terminal passenger service facility airport serve leasehold improvement
# 129                                                               the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 104                                                                                                                      while customer pay difference airfare customer charge change fee difference airfare
# 544                                                                                    landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 495                                                             on july court grant motion certify class person pay bag fee airtran delta december november date airtran stop charge bag fee bag_fee bag_fee
# 221  aircraft rental landing fee rental depreciation amortization acquisition integration other operating expense total operating expense operating income other expenses income 938__Acquisition aircraf...
# 558                                                                                                                               no show policy fund apply future travel southwest change fee future_travel
# 143                                                               the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 480                                                             on july court grant motion certify class person pay bag fee airtran delta december november date airtran stop charge bag fee bag_fee bag_fee
# 133                                                               the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 230                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 240                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 409                                                                                                                                                  -PRON- seek treble damage injunctive relief fee expense
# 246                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 559                                                                                                                               no show policy fund apply future travel southwest change fee future_travel
# 525                                                                                    landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 20                                                                        amount collect passenger ancillary service fee generally recognize other revenue service provide typically flight date flight_date
# 8                                                                         amount collect passenger ancillary service fee generally recognize other revenue service provide typically flight date flight_date
# 225                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
#
#                                                                                                                                                                                                         doc2  \
# 506  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 169  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 623       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 598  the complaint allege thing airtran attempt monopolize air travel violation section sherman act conspire delta impose bag fee item check luggage violation section sherman act the_Sherman_Act Sectio...
# 384                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 239                               aircraft rental landing fee rental depreciation amortization acquisition integration aircraft_rental landing_fee depreciation_and_amortization acquisition_and_integration
# 497       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 594                                                             on july court grant motion certify class person pay bag fee airtran delta december november date airtran stop charge bag fee bag_fee bag_fee
# 517                                                                    the campaign highlight importance southwest customer service show southwest understand plan change charge change fee customer_service
# 444  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 617                                                                    the campaign highlight importance southwest customer service show southwest understand plan change charge change fee customer_service
# 448  the complaint allege thing airtran attempt monopolize air travel violation section sherman act conspire delta impose bag fee item check luggage violation section sherman act the_Sherman_Act Sectio...
# 631  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 174  on dollar basis increase equally attributable high personnel expense associate travel cost company flight crew credit card fee pay party associate increase passenger revenue dollar_basis expense_a...
# 166                                                                    the campaign highlight importance southwest customer service show southwest understand plan change charge change fee customer_service
# 431  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 522       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 595  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 383  aircraft rental landing fee rental depreciation amortization acquisition integration other operating expense total operating expense operating income other expenses income 938__Acquisition aircraf...
# 214                               aircraft rental landing fee rental depreciation amortization acquisition integration aircraft_rental landing_fee depreciation_and_amortization acquisition_and_integration
# 620  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 523  the complaint allege thing airtran attempt monopolize air travel violation section sherman act conspire delta impose bag fee item check luggage violation section sherman act the_Sherman_Act Sectio...
# 317  on asm basis landing fee rental expense decrease percent compare dollar increase offset percent increase capacity asm_basis landing_fee rental_expense decrease_percent compare_with_as_the_dollar i...
# 462  for aircraft operating lease terminal operation lease expense record straight line basis include aircraft rental landing fee rental respectively consolidated statement income operating_lease strai...
# 581  the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 172       on august court dismiss claim airtran delta violate section sherman act court let stand claim conspiracy respect imposition bag fee capacity pricing decision Section_2_of_the_Sherman_Act bag_fee
# 55   the passenger protection rules require airline pay compensation passenger deny boarding involuntarily oversold flight ii refund check bag fee permanently lose luggage iii prominently disclose pote...
# 152                  for example company transfarencysm campaign emphasize southwest approach treat customer fairly honestly respectfully low fare unexpected bag fee change fee hidden fee low_fare bag_fee
# 645  the passenger protection rules require advertise airfare include governmentmandat tax fee ii passenger allow hold reservation hour make payment iii passenger allow cancel pay reservation penalty h...
# 524  on dollar basis increase equally attributable high personnel expense associate travel cost company flight crew credit card fee pay party associate increase passenger revenue dollar_basis expense_a...
# ..                                                                                                                                                                                                       ...
# 227                  for example company transfarencysm campaign emphasize southwest approach treat customer fairly honestly respectfully low fare unexpected bag fee change fee hidden fee low_fare bag_fee
# 58                                              landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 334                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 237        the plaintiff remain complaint generally seek damage include punitive damage certain case prejudgment interest disgorgement benefit accrue defendant result allegation injunctive relief fee cost
# 108                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 229                                                                                                                      while customer pay difference airfare customer charge change fee difference airfare
# 45                                                                                     landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 526                                                                         ground facilities services southwest lease pay usage fee terminal passenger service facility airport serve leasehold improvement
# 120                                                                                    landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 529                                                                                                                      while customer pay difference airfare customer charge change fee difference airfare
# 126                                                                         ground facilities services southwest lease pay usage fee terminal passenger service facility airport serve leasehold improvement
# 29                                                                the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 129                                                                                                                      while customer pay difference airfare customer charge change fee difference airfare
# 104                                                               the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 544                                                             on july court grant motion certify class person pay bag fee airtran delta december november date airtran stop charge bag fee bag_fee bag_fee
# 495                                                                                    landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 221                                                                                                                               no show policy fund apply future travel southwest change fee future_travel
# 558  aircraft rental landing fee rental depreciation amortization acquisition integration other operating expense total operating expense operating income other expenses income 938__Acquisition aircraf...
# 143                                                             on july court grant motion certify class person pay bag fee airtran delta december november date airtran stop charge bag fee bag_fee bag_fee
# 480                                                               the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 133                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 230                                                               the company currently expect landing fee rental expense asm quarter comparable quarter company_currently_expect landing_fee rental_expense
# 240                                                                                                                                                  -PRON- seek treble damage injunctive relief fee expense
# 409                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 246                                                                                                                               no show policy fund apply future travel southwest change fee future_travel
# 559                                             landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 525                                                                       amount collect passenger ancillary service fee generally recognize other revenue service provide typically flight date flight_date
# 20                                                                                     landing fee rental expense increase million percent compare landing_fee rental_expense increase_by_million_or_percent
# 8                                               landing fee rental depreciation amortization acquisition integration 13.9__Acquisition landing_fee depreciation_and_amortization acquisition_and_integration
# 225                                                                       amount collect passenger ancillary service fee generally recognize other revenue service provide typically flight date flight_date
#
#      similarity
# 506    0.976786
# 169    0.976786
# 623    0.972476
# 598    0.972476
# 384    0.964695
# 239    0.964695
# 497    0.962733
# 594    0.962733
# 517    0.959896
# 444    0.959896
# 617    0.957873
# 448    0.957873
# 631    0.957348
# 174    0.957348
# 166    0.957025
# 431    0.957025
# 522    0.955164
# 595    0.955164
# 383    0.954986
# 214    0.954986
# 620    0.954607
# 523    0.954607
# 317    0.953440
# 462    0.953440
# 581    0.953368
# 172    0.953368
# 55     0.951148
# 152    0.951148
# 645    0.951034
# 524    0.951034
# ..          ...
# 227    0.836841
# 58     0.836841
# 334    0.834920
# 237    0.834920
# 108    0.834652
# 229    0.834652
# 45     0.833824
# 526    0.833824
# 120    0.832799
# 529    0.832799
# 126    0.832320
# 29     0.832320
# 129    0.830235
# 104    0.830235
# 544    0.826017
# 495    0.826017
# 221    0.825241
# 558    0.825241
# 143    0.823975
# 480    0.823975
# 133    0.822906
# 230    0.822906
# 240    0.822657
# 409    0.822657
# 246    0.821483
# 559    0.821483
# 525    0.806922
# 20     0.806922
# 8      0.782366
# 225    0.782366
#
# [650 rows x 3 columns]

# %% [markdown]
# ### Index Documents

# %%
dictionary = corpora.Dictionary.load(GENSIM_DICTIONARY_PATH)
corpus = corpora.MmCorpus(GENSIM_CORPUS_PATH)

# %%
print(dictionary)
print(corpus)
# Out:
# Dictionary(134 unique tokens: ['show', 'apply', 'travel', 'southwest', 'change']...)
# MmCorpus(32 documents, 134 features, 419 non-zero entries)

# %%
lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=2)
lsi_corpus = lsi[corpus]

# %%
# index all the documents

# %%
from gensim.similarities import MatrixSimilarity, SparseMatrixSimilarity, Similarity

# transform corpus to LSI space and index it
index = similarities.MatrixSimilarity(lsi[corpus]) 


index.save(SIMILARITY_INDEX)
#index = similarities.MatrixSimilarity.load(SIMILARITY_INDEX)

# %%
# add new documents to the index
# useful to continually add new documents to search against
index.add_documents(lsi_corpus)

# %%
# initialize the index
#%time index_dense = MatrixSimilarity(lsi_corpus, num_features=lsi_corpus.num_terms)
#index = similarities.Similarity(SIMILARITY_INDEX,lsi_corpus, num_features=lsi_corpus.num_terms) # transform corpus to LSI space and index it

# %% [markdown]
# ### Similarity Query

# %%
doc = "Airline fee for landing_fee"
vec_bow = dictionary.doc2bow(doc.lower().split())
vec_lsi = lsi[vec_bow] # convert the query to LSI space
print(vec_lsi)
# Out:
# [(0, -0.10312934054394524), (1, 0.34198630506276362)]

# %%
sims = index[vec_lsi] # perform a similarity query against the corpus
sims
# Out:
# array([ 0.59441066,  0.83202821,  0.83202821,  0.31721264,  0.37263808,
#         0.22230884,  0.22230884,  0.33240592,  0.78784192,  0.21768281,
#         0.5102374 ,  0.5102374 ,  0.99999094,  0.35403904,  0.45829552,
#         0.62159282,  0.62159282,  0.95994979,  0.61456001,  0.98673123,
#         0.8169539 ,  0.9634344 ,  0.97074395,  0.97286832,  0.9840433 ,
#         0.9642309 ,  0.97074395,  0.97286832,  0.90252972,  0.96595037,
#         0.29459408,  0.97178912], dtype=float32)

# %%
# set the number of matches to return (sorted by most relevant)
index.num_best = 3
print(index[vec_lsi])
# Out:
# [(12, 0.99999094009399414), (19, 0.98673123121261597), (24, 0.98404330015182495)]

# %%
# NOTE: These queries only consider semantic similarity, and ignore important behavior driven features

# %% [markdown]
# ### The Norm

# %% [markdown]
# ### Cosine Similarity

# %%
sqlalchemy_url = 'http://blog.christianperone.com/2013/09/machine-learning-cosine-similarity-for-vector-space-models-part-iii/'
iframe = '<iframe src={} width=1100 height=300></iframe>'.format(sqlalchemy_url)
HTML(iframe)
# Out:
# <iframe src=http://blog.christianperone.com/2013/09/machine-learning-cosine-similarity-for-vector-space-models-part-iii/ width=1100 height=300></iframe>

# %% [markdown]
# The similarity in vector space models is determined by using associative coefficients based on the inner product of the document vector and query vector, where word overlap indicates similarity. The inner product is usually normalized. The most popular similarity measure is the cosine coefficient, which measures the angle between the a document vector and the query vector.
#
# SOURCE: http://cogsys.imm.dtu.dk/thor/projects/multimedia/textmining/node5.html
#
# Think about it this way. In the numerator of cosine similarity, only terms that exist in both documents contribute to the dot product. If both of the term have high tfidf values, then they add a lot to the numerator. If a term does not exist in either documents, then it adds nothing to the numerator. On the other hand, the deonominator normalizes the documents, so that a document with many terms is punished with a larger denominator.
